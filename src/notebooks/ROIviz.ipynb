# %%
# %reload_ext autoreload
# %autoreload 2

from pathlib import Path
import sys 

project_root = Path().cwd()
scripts_dir = project_root / "src" / "scripts"
sys.path.insert(0, str(scripts_dir))


import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from scalebars import add_scalebar

import trackcells as tc

# NOTE: 1.2495 microns per pixel

# %%
'''
/Users/savani/Downloads/2p_data/roi files
GLP17
'/Users/savani/Downloads/2p data temp/glp17_fed_d4/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp17_fasted_d1/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp17_fasted_d2/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp17_fasted_d3/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp17_fasted_d5/suite2p/plane0'

GLP23
'/Users/savani/Downloads/2p data temp/glp23_fed_d3/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp23_fasted_d1/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp23_fasted_d2/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp23_fasted_d4/suite2p/plane0'
'/Users/savani/Downloads/2p data temp/glp23_fasted_d5/suite2p/plane0'
'''
suite2p_path =  '/Users/savani/Downloads/2p data temp/glp23_fed_d3/suite2p/plane0'
suite2p_path2 = '/Users/savani/Downloads/2p data temp/glp23_fasted_d5/suite2p/plane0'

suite2p_path ='/Users/savani/Documents/PangLab/TwoPhotonAnalysis/src/data/fasted 30 sucrose/glp6_fastedNoCues_L180_P815_600um-_-03092024-1421-084/suite2p/plane0'
suite2p_path2 = '/Users/savani/Documents/PangLab/TwoPhotonAnalysis/src/data/fed 30 sucrose/glp6_fedNoCues_L180P815_600um-03062024-1321-073/suite2p/plane0'




img1,cells1,stat1,ops1 = tc.get_rois(suite2p_path,rois_on=True)
img1 = img1.astype(float)
img1[img1 == 0] = np.nan

fig, (ax, ax2) = plt.subplots(1, 2, figsize=(15, 10))

meanimg1 = ops1['meanImg']
ax.imshow(meanimg1,cmap = 'gray') ######
ax.imshow(img1, cmap="BuPu", alpha=0.4)
for i in range(0,len(cells1)):
    ax.annotate(cells1[i],xy = (stat1[cells1[i]]['med'][1],stat1[cells1[i]]['med'][0]), c='pink', fontsize=8.5)
    
img2,cells2,stat2,ops2 = tc.get_rois(suite2p_path2,rois_on=True)
img2 = img2.astype(float)
img2[img2 == 0] = np.nan
meanimg2 = ops2['meanImg']
ax2.imshow(meanimg2,cmap = 'gray') ######
ax2.imshow(img2, cmap="gist_ncar", alpha=0.4)
for i in range(0,len(cells2)):
    ax2.annotate(cells2[i],xy = (stat2[cells2[i]]['med'][1],stat2[cells2[i]]['med'][0]), c='pink', fontsize=8.5)

ax.set_xticks([])
ax.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
sns.despine(left=True, bottom=True)
plt.tight_layout(pad=0.2)

img1,cells1,stat1,ops1 = tc.get_rois(suite2p_path,rois_on=True)
img1 = img1.astype(float)
img1[img1 == 0] = np.nan


fig, (ax, ax2) = plt.subplots(1, 2, figsize=(15, 10))
meanimg1 = ops1['meanImg']
ax.imshow(meanimg1,cmap = 'gray') ######
#ax.imshow(img1, cmap=ListedColormap(['red']), alpha=0.4)

    
img2,cells2,stat2,ops2 = tc.get_rois(suite2p_path2,rois_on=True)
img2 = img2.astype(float)
img2[img2 == 0] = np.nan
meanimg2 = ops2['meanImg']
ax2.imshow(meanimg2,cmap = 'gray') ######
#ax2.imshow(img2, cmap=ListedColormap(['red']), alpha=0.4)

ax.set_xticks([])
ax.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
sns.despine(left=True, bottom=True)
plt.tight_layout(pad=0.2)

# %%
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
suite2p_path = '/Users/savani/Documents/PangLab/TwoPhotonAnalysis/src/data/fasted 30 sucrose/glp6_fastedNoCues_L180_P815_600um-_-03092024-1421-084/suite2p/plane0'
from cmap import Colormap

img1,cells1,stat1,ops1 = tc.get_rois(suite2p_path,rois_on=True)
img1 = img1.astype(float)
img1[img1 == 0] = np.nan
cm = Colormap({0.0: "green", 0.5: "green", 1.0: "green"}).to_mpl()
# cm = Colormap({0.0: "darkgreen", 0.5: "lightgreen", 1.0: "green"}).to_mpl()
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# meanimg1 = ops1['meanImg']
# ax.imshow(meanimg1,cmap = 'gray') # shows mean image 
# ax.imshow(img1, cmap="Greens") # adds circles
# ax.imshow(img1, cmap=Colormap('Greens').to_mpl().resampled(lutsize=1)) # adds circles
ax.imshow(img1, cmap='binary') # adds circles

# for i in range(0,len(cells1)): # adds texts 
#     ax.annotate(cells1[i],xy = (stat1[cells1[i]]['med'][1],stat1[cells1[i]]['med'][0]), c='yellow', fontsize=8.5)

ax.set_xticks([])
ax.set_yticks([])
sns.despine(left=True, bottom=True)
# sb = add_scalebar(ax, matchx=False, sizex=100*1.2495, labelx='100 µm', matchy=False, sep=4, sizey=0, hidex=False, hidey=False, labely='',loc='lower left', bbox_to_anchor=(10, 1, 0.1, 0.4))
# plt.savefig('/Users/savani/Documents/PangLab/TwoPhotonAnalysis/figures/2p/2p representative/glp6_fasted_masks.pdf')

# %%
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(14),
#  np.int64(17),
#  np.int64(18),
#  np.int64(19),
#  np.int64(20),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(44),
#  np.int64(45),
#  np.int64(46),
#  np.int64(47),
#  np.int64(49),
#  np.int64(51)]

# %%
suite2p_path = '/Users/savani/Documents/PangLab/TwoPhotonAnalysis/src/data/fasted 30 sucrose/glp6_fastedNoCues_L180_P815_600um-_-03092024-1421-084/suite2p/plane0'
from cmap import Colormap
from matplotlib.colors import ListedColormap


img1,cells1,stat1,ops1 = tc.get_rois(suite2p_path,rois_on=True)
img1 = img1.astype(float)
img1[img1 == 0] = np.nan
cm = Colormap({0.0: "green", 0.5: "green", 1.0: "green"}).to_mpl()
# cm = Colormap({0.0: "darkgreen", 0.5: "lightgreen", 1.0: "green"}).to_mpl()
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
import colorsys

n_labels = 44
colors = np.ones((n_labels + 1, 3)) * 1.0  # Light background (white-ish for label 0)
colors = np.ones((n_labels + 1, 3)) * 0.5  # Very light gray, not pure white


for i in range(0, n_labels + 1):
    hue = np.random.uniform(0.6, 0.65)         # Blue to blue-violet
    saturation = np.random.uniform(0.4, 0.6)    # Medium saturation
    value = np.random.uniform(0.6, 0.8)         # Medium brightness = darker
    rgb = colorsys.hsv_to_rgb(hue, saturation, value)
    colors[i] = rgb

green_cmap = ListedColormap(colors)
ax.imshow(img1, cmap=green_cmap) # adds circles

# for i in range(0,len(cells1)): # adds texts 
#     ax.annotate(cells1[i],xy = (stat1[cells1[i]]['med'][1],stat1[cells1[i]]['med'][0]), c='yellow', fontsize=8.5)

ax.set_xticks([])
ax.set_yticks([])
sns.despine(left=True, bottom=True)
# sb = add_scalebar(ax, matchx=False, sizex=100*1.2495, labelx='100 µm', matchy=False, sep=4, sizey=0, hidex=False, hidey=False, labely='',loc='lower left', bbox_to_anchor=(10, 1, 0.1, 0.4))
plt.savefig('/Users/savani/Documents/PangLab/TwoPhotonAnalysis/figures/2p/2p representative/glp6_fasted_masks_randblue.pdf')
